# %% [markdown]
# # **Encoder - Decoder for Natural Language Processing**
#
# In this exercise we will see how to implement a working Encoder-Decoder architecture to solve an English - Italian translation task. <br/>
# The following notebook will range from the pre-processing of data, the construction of a usable dataset to the design of an architecture based firstly solely on RNNs, and subsequently with the introduction of an Attention layer.

# %% [markdown]
# ## The Dataset

# %%
# !wget https://www.manythings.org/anki/ita-eng.zip
# !unzip ita-eng.zip
# Out:
# --2023-11-14 08:20:36--  https://www.manythings.org/anki/ita-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8220355 (7.8M) [application/zip]
# Saving to: ‘ita-eng.zip’
#
# ita-eng.zip         100%[===================>]   7.84M  13.6MB/s    in 0.6s
#
# 2023-11-14 08:20:37 (13.6 MB/s) - ‘ita-eng.zip’ saved [8220355/8220355]
#
# Archive:  ita-eng.zip
#   inflating: ita.txt
#   inflating: _about.txt

# %%
import os
import torch
import random
import numpy as np

SEED = 124564

def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(SEED)

# %%
import pandas as pd

df = pd.read_csv("ita.txt", sep="\t", header=None, names=["english", "italian", "attrib"])
df.drop(["attrib"], axis=1, inplace=True)

df = df.drop_duplicates().dropna().reset_index(drop=True)

df
# Out:
#                                                   english  \
# 0                                                     Hi.
# 1                                                     Hi.
# 2                                                    Run!
# 3                                                    Run!
# 4                                                    Run!
# ...                                                   ...
# 373166  I know that adding sentences only in your nati...
# 373167  I know that adding sentences only in your nati...
# 373168  I know that adding sentences only in your nati...
# 373169  Doubtless there exists in this world precisely...
# 373170  Doubtless there exists in this world precisely...
#
#                                                   italian
# 0                                                   Ciao!
# 1                                                   Ciao.
# 2                                                  Corri!
# ...

# %% [markdown]
# <font color='red'>**Question #1**</font> <br>
# *What useful statistics can be extracted from the dataset?* <br>
# *How can we exploit them in the construction of the network?*

# %% [markdown]
# Preprocessing

# %%
import unicodedata
import re

def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z]+", r" ", s)
    return s.strip()

# %% [markdown]
# The *Lang* class will serve as vocabulary for the Embedding layer of our architecture. <br>
# Please note the three special tokens...

# %%
class Lang():

    def __init__(self, name, initial_sentences):
        self.name = name
        self.word2index = {"PAD": 0, "SOS": 1, "EOS": 2}
        self.word2count = {"PAD": 0, "SOS": 0, "EOS": 0}
        self.index2word = {0: "PAD", 1: "SOS", 2: "EOS"}
        self.n_words = 3

        for sentence in initial_sentences:
            self.addSentence(sentence)


    def addSentence(self, sentence):
        sentence = normalizeString(unicodeToAscii(sentence))

        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

eng_lang = Lang("english", df.english.tolist())
ita_lang = Lang("italian", df.italian.tolist())

print(f"Added {eng_lang.n_words} English words and {ita_lang.n_words} Italian words.")
# Out:
# Added 13610 English words and 27230 Italian words.

# %% [markdown]
# Let's build the PyTorch Dataset and Dataloader <br><br>
#
# *Documentation: <br>
# <a href="https://pytorch.org/docs/stable/data.html">torch.utils.data</a><br>*

# %%
from torch.utils.data import Dataset
import torch

class TranslationDataset(Dataset):

    def __init__(self, df, in_lang, out_lang, max_len):
        self.df = df
        self.in_lang = in_lang
        self.out_lang = out_lang
        self.max_len = max_len

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):

        # Prepare input sentence.
        inp_sent = normalizeString(unicodeToAscii(self.df.iloc[idx][self.in_lang.name]))

        inp_list = inp_sent.split(' ')[:self.max_len-1] + ["EOS"]       # Truncation
        inp_list = inp_list + ["PAD"]*(self.max_len - len(inp_list))    # Padding

        inp_indexes = [self.in_lang.word2index[word] for word in inp_list]

        # Prepare output sentence.
        out_sent = normalizeString(unicodeToAscii(self.df.iloc[idx][self.out_lang.name]))

        out_list = ["SOS"] + out_sent.split(' ')[:self.max_len-2] + ["EOS"]
        out_list = out_list + ["PAD"]*(self.max_len - len(out_list))

        out_indexes = [self.out_lang.word2index[word] for word in out_list]

        return torch.tensor(inp_indexes, dtype=torch.long), torch.tensor(out_indexes, dtype=torch.long)

# %%
df_train = df.sample(frac=0.8, random_state=SEED).reset_index(drop=True)

df_test = df.drop(df_train.index).reset_index(drop=True)
df_val = df_test.sample(frac=0.5, random_state=SEED).reset_index(drop=True)

df_test = df_test.drop(df_val.index).reset_index(drop=True)


print(f"#Train examples: {len(df_train)}")
print(f"#Val   examples: {len(df_test)}")
print(f"#Test  examples: {len(df_val)}")
# Out:
# #Train examples: 298537
# #Val   examples: 37317
# #Test  examples: 37317

# %%
from torch.utils.data import DataLoader

MAX_LEN = 14
BATCH_SIZE = 64

train_dataset = TranslationDataset(df_train, eng_lang, ita_lang, MAX_LEN)
val_dataset = TranslationDataset(df_val, eng_lang, ita_lang, MAX_LEN)
test_dataset = TranslationDataset(df_test, eng_lang, ita_lang, MAX_LEN)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# %%
train_loader

# %% [markdown]
# ## The Encoder-Decoder Architecture
#
# Finally, in this section we will start coding our PyTorch architecture. <br><br>
# *Documentation: <br>
# <a href="https://pytorch.org/docs/stable/nn.html">torch.nn</a><br>*

# %% [markdown]
# **Encoder** <br>
# Reads the source sentence and
# produces its representation

# %%
from torch.nn.modules import dropout
from torch.nn.modules.sparse import Embedding
from IPython.terminal.embed import embed
import torch.nn as nn
import torch.nn.functional as F


class EncoderRNN(nn.Module):
  def __init__(self, inputs, es, hs, dr=0.1):
    super(EncoderRNN, self).__init__()
    self.embedding=nn.Embedding(inputs,es)
    self.gru=nn.GRU(es,hs, batch_first=True)
    self.dropout=nn.Dropout(dr)

  def forward(self, input):
    embedded=self.dropout((self.embedding(input)))
    output, hidden=self.gru(embedded)
    return output,hidden

# %% [markdown]
# **RNN Decoder** <br>
# Uses source representation
# from the encoder to generate the target
# sentence

# %%
class DecoderRNN(nn.Module):
  def __init__(self, embedding_size, hidden_size,output_size, max_len,device, sos_token_indx):
    super(DecoderRNN, self).__init__()
    self.max_len=max_len
    self.device=device
    self.sos_token_indx=sos_token_indx
    self.embedding= nn.Embedding(output_size, embedding_size)
    self.GRU=nn.GRU(embedding_size, hidden_size, batch_first=True)
    self.expansion=nn.Linear(hidden_size, output_size)

  def forward_step(self, input, hidden):
    output=self.embedding(input)
    output, hidden=self.GRU(output,hidden)
    output=self.expansion(output)
    return output, hidden

  def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
    decoder_input=torch.tensor([[self.sos_token_indx]]* encoder_outputs.size(0), dtype=torch.long,device=self.device
                              )

    decoder_hidden=encoder_hidden
    decoder_outputs=[]

    for i in range(self.max_len):
      decoder_output, decoder_hidden= self.forward_step(decoder_input, decoder_hidden)
      decoder_outputs.append(decoder_output)

      if target_tensor is not None:
        decoder_input=target_tensor[:,i].unsqueeze(1)
      else:
        _, topi=decoder_output.topk(1)
        decoder_input=topi.squeeze(-1)

    decoder_outputs=torch.cat(decoder_outputs, dim=1)
    decoder_outputs=F.log_softmax(decoder_outputs, dim=-1)

    return decoder_outputs, decoder_hidden, None

# %% [markdown]
# **Encoder-Decoder Architecture**

# %%
import copy
from tqdm import tqdm
from torch.optim import Adam
from torch.cuda.amp import autocast, GradScaler
from sklearn.metrics import accuracy_score


class EncoderDecoder(nn.Module):

    def __init__(self, encoder, decoder, model_name, device):
        super(EncoderDecoder, self).__init__()

        self.model_name = model_name
        self.device = device
        self.encoder = encoder
        self.decoder = decoder


    def forward(self, input_tensor, target_tensor):
        encoder_outputs, encoder_hidden = self.encoder(input_tensor)
        decoder_outputs, _, _ = self.decoder(encoder_outputs, encoder_hidden, target_tensor)

        return decoder_outputs


    def train_architecture(self, train_data, val_data, epochs, criterion, optimizer, scaler):

        train_losses = []
        val_losses = []
        accuracies = []
        best_valloss = np.Inf
        best_ep = 0
        best_model = copy.deepcopy(self.state_dict())

        for ep in tqdm(range(epochs)):
            self.train()
            ep_loss = 0.0

            for batch in train_data:

                optimizer.zero_grad()
                input_tensor, target_tensor = [b.to(self.device) for b in batch]

                with autocast():
                    output_tensor = self(input_tensor, target_tensor)

                    # Flatten the tensor on the batch_size x seq_len:
                    # output_tensor: (64, 14, 27230) -> (896, 27230)
                    # target_tensor: (64, 14) -> (896)
                    loss = criterion(output_tensor.view(-1, output_tensor.size(-1)), target_tensor.view(-1))

                ep_loss += loss.item()

                # Backpropagation
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

            train_losses.append(ep_loss/len(train_data))

            # Evaluation

            val_loss, accuracy = self.eval_model(val_data, criterion)
            accuracies.append(accuracy)
            val_losses.append(val_loss)

            if val_loss < best_valloss:
                best_valloss = val_loss
                best_model = copy.deepcopy(self.state_dict())
                best_ep = ep+1

            torch.save(best_model, f"models/{self.model_name}.pth")

        return train_losses, accuracies, val_losses, best_ep, best_valloss


    def eval_model(self, val_data, criterion):
        self.eval()

        val_loss = 0.0
        val_preds = []
        val_labels = []

        with torch.no_grad():
            for batch in val_data:
                input_tensor, target_tensor = [b.to(self.device) for b in batch]

                with autocast():
                    output_tensor = self(input_tensor, target_tensor)
                    loss = criterion(output_tensor.view(-1, output_tensor.size(-1)), target_tensor.view(-1))

                    predictions = output_tensor.argmax(dim=-1)

                val_loss += loss.item()
                val_preds.extend(predictions.cpu().numpy().flatten())
                val_labels.extend(target_tensor.cpu().numpy().flatten())

        return val_loss/len(val_data), accuracy_score(val_labels, val_preds)


    def generate(self, test_data):
        self.eval()

        test_preds = []
        test_labels = []

        with torch.no_grad():
            for batch in test_data:
                input_tensor, target_tensor = [b.to(self.device) for b in batch]

                with autocast():
                    output_tensor = self(input_tensor, target_tensor)
                    predictions = output_tensor.argmax(dim=-1)

                test_preds.extend(predictions.cpu().numpy().flatten())
                test_labels.extend(target_tensor.cpu().numpy().flatten())

        return test_preds, test_labels

# %% [markdown]
# <font color='red'>**Question #2**</font> <br>
# *Can random embedding initialisation penalise model training?* <br>
# *How can we solve it?* <br><br>
#
# <font color='red'>**Question #3**</font> <br>
#
# *Is the GRU the only RNN that can be implemented in an encoder/decoder architecture?*

# %% [markdown]
# **Training** <br>
# Negative log likelihood loss.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device loaded: {device}")

embedding_size = 128
hidden_size = 256
drop_rate = 0.1
lr = 0.001
epochs = 5

input_lang = eng_lang
output_lang = ita_lang
sos_token = input_lang.word2index["SOS"]
pad_token = input_lang.word2index["PAD"]


criterion = nn.NLLLoss(ignore_index=pad_token)
scaler = GradScaler()
# Out:
# Device loaded: cpu
# /usr/local/lib/python3.10/dist-packages/torch/cuda/amp/grad_scaler.py:125: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(

# %%
# !mkdir -p models

rnn_encoder = EncoderRNN(input_lang.n_words, embedding_size, hidden_size, drop_rate)
rnn_decoder = DecoderRNN(embedding_size, hidden_size, output_lang.n_words, MAX_LEN, device, sos_token)

rnn_model = EncoderDecoder(rnn_encoder, rnn_decoder, "plain", device).to(device)
optimizer = Adam(rnn_model.parameters(), lr=lr)

print("Training the model...")
train_losses, accuracies, val_losses, best_ep, best_valloss = rnn_model.train_architecture(train_loader, val_loader, epochs, criterion, optimizer, scaler)

print(f"\n\nBest model at epoch {best_ep} with val loss {round(best_valloss, 4)}")
# Out:
# Training the model...
#   0%|          | 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  20%|██        | 1/5 [2:00:59<8:03:59, 7259.95s/it]/usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  40%|████      | 2/5 [4:01:25<6:01:59, 7239.85s/it]/usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(train_losses, label="Train loss")
plt.plot(val_losses, label="Validation loss")
plt.ylim(0, 5)
plt.legend()
plt.show()


plt.figure(figsize=(10, 5))
plt.plot(accuracies, label="Accuracy")
plt.ylim(0, 1)
plt.legend()
plt.show()

# %% [markdown]
# ## The Attention Decoder

# %%
class BahdanauAttention(nn.Module):
  def __init__(self, hidden_size):
    super(BahdanauAttention, self).__init__()
    self.Wa=nn.Linear(hidden_size,hidden_size)
    self.Ua=nn.Linear(hidden_size,hidden_size)
    self.Va=nn.Linear(hidden_size,1)

  def forward(self, last_decoder_output, encoder_output):
    scores=self.Va(torch.tanh(self.Wa(last_decoder_output)+ self.Ua(encoder_output)))
    scores=scores.squeeze(2).unsqueeze(1)
    weights=F.softmax(scores,dim=1)
    context=torch.bmm(weights,encoder_outputs)

    return context, weights



class AttDecoderRNN(nn.Module):
  def __init__(self, embedding_size, hidden_size,output_size, dropout_rate, max_len,device, sos_token_indx):
    super(AttDecoderRNN, self).__init__()
    self.max_len=max_len
    self.device=device
    self.sos_token_indx=sos_token_indx
    self.embedding= nn.Embedding(output_size, embedding_size)
    self.GRU=nn.GRU(hidden_size+embedding_size, hidden_size, batch_first=True)
    self.expansion=nn.Linear(hidden_size, output_size)
    self.dropout=nn.Dropout(dropout_rate)

  def forward_step(self, input, hidden, encoder_outputs):
    embedded=self.dropout(self.embedding(input))
    context, aw=self.attention(hidden.permute(1,0,2),encoder_outputs)
    i_gru=torch.cat(embedded,context, dim=2)

    output, hidden=self.GRU(i_gru,hidden)
    output=self.expansion(output)
    return output, hidden, aw

  def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
    decoder_input=torch.tensor([[self.sos_token_indx]]* encoder_outputs.size(0), dtype=torch.long,device=self.device
                              )

    decoder_hidden=encoder_hidden
    decoder_outputs=[]
    attention=[]

    for i in range(self.max_len):
      decoder_output, decoder_hidden, att_weights= self.forward_step(decoder_input, decoder_hidden)
      decoder_outputs.append(decoder_output)
      attention.append(aw)
      if target_tensor is not None:
        decoder_input=target_tensor[:,i].unsqueeze(1)
      else:
        _, topi=decoder_output.topk(1)
        decoder_input=topi.squeeze(-1)

    decoder_outputs=torch.cat(decoder_outputs, dim=1)
    decoder_outputs=F.log_softmax(decoder_outputs, dim=-1)
    attentions= torch.cat(attention, dim=1)

    return decoder_outputs, decoder_hidden, attention

# %%
att_encoder = EncoderRNN(input_lang.n_words, embedding_size, hidden_size, drop_rate)
att_decoder = AttDecoderRNN(embedding_size, hidden_size, output_lang.n_words, drop_rate, MAX_LEN, device, sos_token)

att_model = EncoderDecoder(att_encoder, att_decoder, "attention", device).to(device)
optimizer = Adam(att_model.parameters(), lr=lr)

print("Training the model...")
att_train_losses, att_accuracies, att_val_losses, best_ep, best_valloss = att_model.train_architecture(train_loader, val_loader, epochs, criterion, optimizer, scaler)

print(f"\n\nBest model at epoch {best_ep} with val loss {round(best_valloss, 4)}")

# %%
plt.figure(figsize=(10, 5))
plt.plot(att_train_losses, label="Train loss")
plt.plot(att_val_losses, label="Validation loss")
plt.ylim(0, 5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(accuracies, label="Plain Model")
plt.plot(att_accuracies, label="Attention Model")
plt.ylim(0, 1)
plt.legend()
plt.show()

# %% [markdown]
# <font color='red'>**Question #4**</font> <br>
#
# *If Bahdanau Attetion works that well, how does Luong performs?*

# %% [markdown]
# ## Testing <br>
# BLEU (bilingual evaluation understudy) is an algorithm for evaluating the quality of text which has been machine-translated from one natural language to another. Quality is considered to be the correspondence between a machine's output and that of a human: "the closer a machine translation is to a professional human translation, the better it is". <br>
# **BLEU's output is always a number between 0 and 1.** This value indicates how similar the candidate text is to the reference texts, with values closer to 1 representing more similar texts. <br><br>
# *Documentation:* <br>
#
# <a href="https://www.nltk.org/_modules/nltk/translate/bleu_score.html">NLTK Implementation</a><br>
# <a href="https://aclanthology.org/W14-3346.pdf">EXTRA: SmoothingFunction</a>

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def compute_bleu(labels, preds):
    labels = np.reshape(labels, (round(len(test_preds)/MAX_LEN), MAX_LEN)).tolist()
    preds = np.reshape(preds, (round(len(test_preds)/MAX_LEN), MAX_LEN)).tolist()

    bleus = []
    for ref, cand in zip(labels, preds):
        bleus.append(sentence_bleu([ref], cand, weights=[0.25, 0.25, 0.25, 0.25], smoothing_function=SmoothingFunction().method7))

    return sum(bleus)/len(bleus)

rnn_model.load_state_dict(torch.load(f"models/{rnn_model.model_name}.pth"))
test_preds, test_labels = rnn_model.generate(test_loader)

print(f"Test Accuracy for {rnn_model.model_name} model: {round(accuracy_score(test_labels, test_preds)*100, 2)}%")
print(f"Test BLEU Score for {rnn_model.model_name} model: {round(compute_bleu(test_labels, test_preds), 2)}")

print()

att_model.load_state_dict(torch.load(f"models/{att_model.model_name}.pth"))
test_preds, test_labels = att_model.generate(test_loader)

print(f"Test Accuracy for {att_model.model_name} model: {round(accuracy_score(test_labels, test_preds)*100, 2)}%")
print(f"Test BLEU Score for {att_model.model_name} model: {round(compute_bleu(test_labels, test_preds), 2)}")

# %% [markdown]
# ## **Future Works... some ideas**

# %% [markdown]
# Use *gensim* models as pretrained Embedding <br><br>
#
# *Documentation*:<br>
# <a href="https://github.com/piskvorky/gensim/wiki/Migrating-from-Gensim-3.x-to-4">Gensim useful commands</a>

# %%
import torch
import torch.nn as nn
import gensim.downloader

# Show all available models in gensim-data

print("Gensim available pretrained models:\n")
list(gensim.downloader.info()['models'].keys())

# %% [markdown]
# <font color='red'>**NB: do NOT run the following cell, is too RAM expensive for Colab**</font>

# %%
w2v = gensim.downloader.load('word2vec-google-news-300')

w2v_vocab = w2v.key_to_index

emb_weights = torch.tensor(w2v.get_normed_vectors())    # Cast to tensor
emb = nn.Embedding.from_pretrained(emb_weights)         # Load as layer weights
