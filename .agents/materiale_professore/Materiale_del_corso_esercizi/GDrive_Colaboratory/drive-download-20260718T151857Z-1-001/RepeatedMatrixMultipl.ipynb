# %%
import tensorflow as tf
import sys
import numpy as np

# %%
A = tf.ones([3,3], name='MatrixA', dtype=tf.float32)
A1= tf.random.uniform([3,3], name='MatrixB', dtype=tf.float32)
A=0.1*A
x=tf.constant([0.001,1,10], dtype=tf.float32)
activation=tf.keras.activations.linear
activation=tf.keras.activations.relu
activation=tf.keras.activations.tanh

# %%
B=activation(tf.tensordot(A,x,axes=1))
B
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([0.80053496, 0.80053496, 0.80053496], dtype=float32)>

# %%
for x in range(15):
  
  B=activation(tf.tensordot(A,B,axes=1, name=None))

B
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([1.1250348e-08, 1.1250348e-08, 1.1250348e-08], dtype=float32)>
