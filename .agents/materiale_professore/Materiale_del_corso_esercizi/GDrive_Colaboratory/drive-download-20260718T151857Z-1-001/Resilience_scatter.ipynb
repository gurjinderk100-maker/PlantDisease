# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import matplotlib
import numpy

# In[2]:


domains = ["zenotravel", "storage", "satellite", "driverlog", "rocket", "blocksworldMA", "logistics"]


# In[3]:


#RP data

RP = { i:{domain:[] for domain in domains} for i in range(1,5)}

RP[1]["zenotravel"] = [3.05,17.24,4.03,5.07,4.66,7.2,5.35,5.83,7.09,16.6,7.82,24.71,50.26,314.32,516.07,900.48,1800,1800,1800,1800]
RP[1]["storage"] = [0.97,0.99,1.01,1.18,1.06,1.06,104.31,1.26,1.11,1800,1800,1.8,1800,4.64,3.98,5.43,14.36,345.92,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[1]["satellite"] = [2.55,1800,1.37,1.53,1.41,1800,4.02,1.93,8.31,16.57,10.76,1800,146.31,28.8,73.45,192.17,94.56,14.51,1800,1800,369.32,1571.48,1187.37,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[1]["driverlog"] = [3.11,1.27,1.31,1.34,1.31,1.26,1.33,2.48,3.35,5.36,6.22,21.05,20.18,19.37,1800,1800,1800,1800,1800,1800]
RP[1]["rocket"] = [0.8,1.17,1.18,1.12,1.17,1.16,1.04,1.15,2.29,4.28]
RP[1]["blocksworldMA"] = [1.61,1.44,1.51,1.2,1.4,1.59,3.2,1.63,3.14,2.05]
RP[1]["logistics"] = [1.4,1.5,1.56,1.26,1,1.5,1.48,1.62,4.51,1800]

RP[2]["zenotravel"] = [4.81,13.24,1800,1800,1800,1800,1800,135.89,157.58,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[2]["storage"] = [1.08,1.13,1.15,1.32,393.63,1.35,81.95,1800,3.25,1800,1800,16.25,1800,1800,1800,60.37,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[2]["satellite"] = [2.38,1800,1800,1800,18.1,1800,58.5,71.14,424.98,570.56,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[2]["driverlog"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,11.03,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[2]["rocket"] = [1.24,1.27,1.21,1.26,1.35,1.24,1.56,5.25,17.02,129.03]
RP[2]["blocksworldMA"] = [1.48,1.47,1.48,1.42,2.07,2.18,154.66,1.91,22.37,31.28]
RP[2]["logistics"] = [1.53,4.7,3.1,2.45,7.82,8.47,5.46,6.98,64.51,1800]

RP[3]["zenotravel"] = [3.31,25.4,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[3]["storage"] = [1.06,1.08,1.24,3.26,1800,1800,158.73,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[3]["satellite"]  = [2.7,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[3]["driverlog"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[3]["rocket"] = [2.28,18.57,4.17,15.36,4.19,14.24,22.48,7.55,12.00,1800]
RP[3]["blocksworldMA"] = [1800,1800,1800,1800,4.39,5.33,558.42,7.33,189.82,1800]
RP[3]["logistics"] = [5.4,30.65,18.2,18.0,194.44,320.1,283.67,1800,1800,1800]

RP[4]["zenotravel"] = [5.1,32.36,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[4]["storage"] = [1.17,1.19,1.53,1.73,1243.95,1800,118.66,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[4]["satellite"] = [2.37,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[4]["driverlog"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
RP[4]["rocket"] = [1800,1800,1800,1800,782.6,2.38,1800,1800,1800,1800]
RP[4]["blocksworldMA"] = [1800,1800,1800,1800,12.99,26.33,1710.12,195.54,1800,1800]
RP[4]["logistics"] = [58.99,1800,609.51,486.49,1800,1800,1800,1800,1800,1800]


# In[4]:


#MN data

MN = { i:{domain:[] for domain in domains} for i in range(1,5)}

MN[1]["zenotravel"] = [1.24,2.08,94.4,438.76,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[1]["storage"] = [1.42,1.62,1.67,2.76,2.43,3.82,1162.51,32.23,79.2,1800,1800,1800,1.78,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[1]["satellite"] = [141.52,1800,141.52,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[1]["driverlog"] = [1.46,1800,32.36,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[1]["rocket"] = [4.64,117.29,57.43,130.54,1800,1800,1800,1800,1800,1800]
MN[1]["blocksworldMA"] = [31.47,9.85,35.92,300.49,162.97,1800,1800,1800,1800,1800]
MN[1]["logistics"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]

MN[2]["zenotravel"] = [1.68,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[2]["storage"] = [1.48,1.48,1.6,1.7,1.76,1.78,1.69,1800,1800,1.96,1800,1800,2.12,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[2]["satellite"] = [1800,1800,1800,1800,1800,1800,1682.32,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[2]["driverlog"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[2]["rocket"] = [659.96,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[2]["blocksworldMA"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[2]["logistics"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]

MN[3]["zenotravel"] = [1.62,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[3]["storage"] = [1.49,1.49,1.45,1.6,1.64,1.98,1.81,1800,1800,2.13,1800,1800,2.05,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[3]["satellite"]  = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[3]["driverlog"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[3]["rocket"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[3]["blocksworldMA"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[3]["logistics"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]

MN[4]["zenotravel"] = [2.01,2.43,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[4]["storage"] = [1.49,1.63,1.62,1.58,1.76,1.97,1.83,3.9,1800,2.04,1800,1800,2.13,3.37,3.83,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[4]["satellite"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[4]["driverlog"] = [2.11,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[4]["rocket"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[4]["blocksworldMA"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]
MN[4]["logistics"] = [1800,1800,1800,1800,1800,1800,1800,1800,1800,1800]


#Proven unsovable  problems

PUSov = { i:{domain:[] for domain in domains} for i in range(1,5)}

PUSov[1]["zenotravel"] = [False,True ,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[1]["storage"] = [True,True,True,True,False,False,True,False,False,False,False,False,True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[1]["satellite"] = [True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]
PUSov[1]["driverlog"] = [False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[1]["rocket"] = [False,False,False,False,False,False,False,False,False,False]
PUSov[1]["blocksworldMA"] = [False,False,False,False,False,False,False,False,False,False]
PUSov[1]["logistics"] = [False,False,False,False,False,False,False,False,False,False]



#============================


PUSov[2]["zenotravel"] = [False,True ,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[2]["storage"] = [True,True,True,True,True,True,True,False,False,True,False,False,True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[2]["satellite"] = [True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[2]["driverlog"] = [False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]


PUSov[2]["rocket"] = [False,False,False,False,False,False,False,False,False,False]
PUSov[2]["blocksworldMA"] = [False,False,False,False,False,False,False,False,False,False]
PUSov[2]["logistics"] = [False,False,False,False,False,False,False,False,False,False]

#============================

PUSov[3]["zenotravel"] = [True ,True ,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[3]["storage"] = [True,True,True,True,True,True,True,False,False,True,False,False,True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[3]["satellite"] = [True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[3]["driverlog"] = [False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[3]["rocket"] = [False,False,False,False,False,False,False,False,False,False]
PUSov[3]["blocksworldMA"] = [False,False,False,False,False,False,False,False,False,False]
PUSov[3]["logistics"] = [False,False,False,False,False,False,False,False,False,False]



#============================

PUSov[4]["zenotravel"] = [True ,True ,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[4]["storage"] = [True,True,True,True,True,True,True,True,False,True,False,False,True,True,True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[4]["satellite"] = [True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[4]["driverlog"] = [True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]

PUSov[4]["rocket"] = [False,False,False,False,False,False,False,False,False,False]

PUSov[4]["blocksworldMA"] = [False,False,False,False,False,False,False,False,False,False]

PUSov[4]["logistics"] = [False,False,False,False,False,False,False,False,False,False]



# In[5]:


matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['font.size'] = 13

fig, axs = plt.subplots(1,4, figsize=(15,3))

color1 = plt.cm.viridis(0)
color2 = plt.cm.viridis(0.6)
color3 = plt.cm.viridis(.9)


alpha_v = 1

for i in range(4):
    RP_all = []
    MN_all = []
    PU_all = []
    for domain in domains:
        RP_all += RP[i+1][domain]
        MN_all += MN[i+1][domain]
        PU_all += PUSov[i+1][domain]

    rp=numpy.array(RP_all)
    mn=numpy.array(MN_all)
    pu=numpy.array(PU_all)
    axs[i].set_title("K = {}".format(i+1))
    axs[i].set_xscale("log")
    axs[i].set_yscale("log")
    axs[i].xaxis.set_ticks([1, 10, 100, 1000])
    axs[i].yaxis.set_ticks([1, 10, 100, 1000])
    axs[i].scatter(rp[pu==False],mn[pu==False],color=color1, alpha=alpha_v, marker='x')
    axs[i].scatter(rp[pu==True],mn[pu==True],color=color2, alpha=alpha_v, marker='D')
    axs[i].plot([0,1800],[0,1800],c="black",linestyle=":", lw=0.5, alpha=1)
    
#handles, labels = axs[0].get_legend_handles_labels()
#fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5,-0.2), ncol=len(labels), columnspacing=0.6, bbox_transform=fig.transFigure)

fig.tight_layout()
plt.savefig("scatter.pdf",bbox_inches='tight')

fig, axs = plt.subplots(1,1, figsize=(15,15))

RP_all = []
MN_all = []
PU_all = []

for i in range(4):
    for domain in domains:
        RP_all += RP[i+1][domain]
        MN_all += MN[i+1][domain]
        PU_all += PUSov[i+1][domain]

rp=numpy.array(RP_all)
mn=numpy.array(MN_all)
pu=numpy.array(PU_all)
axs.set_title("all K")
axs.set_xscale("log")
axs.set_yscale("log")
axs.xaxis.set_ticks([1, 10, 100, 1000])
axs.yaxis.set_ticks([1, 10, 100, 1000])
axs.scatter(rp[pu==False],mn[pu==False],color=color1, alpha=alpha_v, marker='x')
axs.scatter(rp[pu==True],mn[pu==True],color=color2, alpha=alpha_v, marker='D')
axs.plot([0,1800],[0,1800],c="black",linestyle=":", lw=0.5, alpha=1)
    
fig.tight_layout()
plt.savefig("all_scatter.pdf",bbox_inches='tight')
