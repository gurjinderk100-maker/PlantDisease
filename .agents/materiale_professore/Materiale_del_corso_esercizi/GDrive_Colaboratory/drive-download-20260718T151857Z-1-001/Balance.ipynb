# %%
 def addInterest(balance, rate):
   newBalance = balance * (1 + rate)
   balance = newBalance
   print("AddInterest current balance is: ", balance)
def test():
    amount = 1000
    rate = 0.05
    addInterest(amount, rate)
    print("My current balance is: ", amount)
test()
